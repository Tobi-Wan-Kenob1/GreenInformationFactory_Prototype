# %% [markdown]
# For a quick test, run the following:

# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parents[0]
if str(repo_root) not in sys.path:
    sys.path.append(str(repo_root))

from helper import load_pipeline_config, save_run_log

cfg = load_pipeline_config()
cfg["ml"]["features"], cfg["ml"]["target"]

log_path = save_run_log("prepare_data", {"message": "config loaded OK"})
log_path
# Out:
# PosixPath('/home/097e80f6-6687-4e65-aab6-9abf7b887006/GreenInformationFactory_Prototype/metadata/runs/prepare_data_20260126T125535Z.json')

# %% [markdown]
# You should see a new JSON log under metadata/runs/….
